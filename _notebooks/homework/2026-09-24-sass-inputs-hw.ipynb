# %% [markdown]
# ---
# layout: post
# codemirror: true
# title: "SASS: Inputs HW"
# categories: [HW]
# lesson_language: SASS
# lesson_topic: Inputs HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /sass/inputs-hw/
# author: ruhaanb622
# ---

# %% [markdown]
# ## Popcorn Hack
#
# Click **Run** to preview the large gradient search field and compact volunteer name field.

# %%
# %%html
# <!-- UI_RUNNER: Popcorn Hack — PVO Input Grammar | interactive: true -->
# <!-- ocs__input provides the shared input styling used by the lesson. -->
# <!-- Size and gradient modifiers change appearance without custom CSS. -->
# <input type="text" class="ocs__input large gradient" placeholder="Search PVO resources...">
# <input type="text" class="ocs__input small" placeholder="Volunteer First Name">

# %% [markdown]
# ## Homework Hack
#
# Click **Run** to preview the three class-based signup fields.

# %%
# %%html
# <!-- UI_RUNNER: Homework Hack — PVO Signup Inputs | interactive: true -->
# <!-- Each field uses the OCS input class plus a size modifier. -->
# <!-- type=email lets the browser recognize the email field correctly. -->
# <input type="text" class="ocs__input large gradient" placeholder="Assistance Category">
# <input type="text" class="ocs__input small" placeholder="Volunteer First Name">
# <input type="email" class="ocs__input medium" placeholder="Volunteer Email">
