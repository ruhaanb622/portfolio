# %% [markdown]
# ---
# layout: post
# codemirror: true
# title: OCS Semantic HTML & Typography Grammar HW
# categories: [HW]
# lesson_language: SASS
# lesson_topic: Typography HW
# lesson_part: interactive
# lesson_type: lesson
# permalink: /sass/typography-hw
# author: ruhaanb622
# ---

# %% [markdown]
# ## Popcorn Hack
#
# Click **Run** in the UI runner to render the heading, subheading, and paragraph below.

# %%
# %%html
# <!-- UI_RUNNER: Popcorn Hack — Semantic HTML Typography | interactive: true -->
# <h1 class="ocs_section-title">This is</h1>
# <h2>a very cool</h2>
# <p class="ocs_lead">lesson</p>

# %% [markdown]
# ## Homework Hack
#
# Click **Run** in the UI runner to render the finished cat instructions as a heading, paragraphs, and a numbered list.

# %%
# %%html
# <!-- UI_RUNNER: Homework Hack — How to Pat a Cat | interactive: true -->
# <div class="ocs_card">
#   <h2 class="ocs_section-title">How to Pat a Cat</h2>
#   <h3>Have you ever wanted to…</h3>
#   <p class="ocs_description">pat a cat? Well good for you we will give step by step instructions on how to pat a cat!</p>
#   <p class="ocs_text"><strong>How to pat a cat:</strong></p>
#   <ol>
#     <li>put out your hand</li>
#     <li>touch the cat</li>
#     <li>move your hand back and forth</li>
#   </ol>
#   <h3>Congrats! You pat a cat :D</h3>
# </div>
